# %%
#Utility
import urllib
import os
import datetime

#Data Science
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from hmmlearn import hmm

#Google API
import google.auth
from google.cloud import bigquery
from google.cloud import bigquery_storage_v1beta2

# %%
#ACCOUNT IS SUSPENDED AT THE MOMENT ----------------------------------------------------
#Big query, requires API json 
#pip install --upgrade google-cloud-bigquery[bqstorage,pandas]
#pip install --upgrade google-auth
#%load_ext google.cloud.bigquery
#os.environ["GOOGLE_APPLICATION_CREDENTIALS"]="Covid-19-be0adf05131c.json"

#%%bigquery jhu_summary
#SELECT * FROM `bigquery-public-data.covid19_jhu_csse.summary`
#jhu_summary['country_region'].value_counts()

# %% [markdown]
# ## Mobility

# %%
#Import mobility from url
url = 'https://www.gstatic.com/covid19/mobility/Global_Mobility_Report.csv'
mobility = pd.read_csv(url)

#Transform mobility to time series
startdate = datetime.datetime.strptime('2020-02-15','%Y-%m-%d').date()
enddate = datetime.datetime.strptime('2020-04-11','%Y-%m-%d').date()

filterlist = ['retail_and_recreation_percent_change_from_baseline',
'grocery_and_pharmacy_percent_change_from_baseline',
'parks_percent_change_from_baseline',
'transit_stations_percent_change_from_baseline',
'workplaces_percent_change_from_baseline',
'residential_percent_change_from_baseline']

clist = ['retail_rec_mobility','grocery_pharmacy_mobility','parks_mobility','transit_mobility','workplaces_mobility','residential_mobility']
# Out:
# C:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3051: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
country = mobility['country_region'].value_counts()
countrylist = country.index.to_list()
usmobility = mobility[mobility['country_region']=='United States']

#Change column names
usmobility = usmobility.rename(columns={"sub_region_1":"Province_State", "sub_region_2": "Admin2"})

#Split county text out of county
countylist = []
txt = usmobility['Admin2'].to_list()
for i in txt:
    i = str(i)
    countylist.append(i.replace(' County', ''))
    
usmobility['Admin2'] = countylist
usmobility['Lookup'] = usmobility['Admin2'] + usmobility['Province_State']
lookuplist = usmobility['Lookup'].to_list()
usmobility = usmobility.transpose()
usmobility.columns = lookuplist
usmobility = usmobility.transpose()
usmobilitylookup = sorted(usmobility['Lookup'].value_counts().index.to_list())

mindatemobility = min(usmobility['date'])
maxdatemobility = max(usmobility['date'])
mobilitytrange = pd.date_range(mindatemobility,maxdatemobility).format('%m/%d/%y')

# %% [markdown]
# ## Cases from John Hopkins

# %%
#Import confirmed cases from url
confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv")
deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv")
recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv")

# %%
df = confirmed.copy()
df.columns
xlist = ['UID', 'iso2', 'iso3', 'code3', 'FIPS','Country_Region', 'Lat', 'Long_','Combined_Key']

df['Lookup'] = df['Admin2'] + df['Province_State']
includelist = [x for x in df.columns if x not in xlist]
datelist = includelist.copy()
datelist.pop(0)
datelist.pop(0)
datelist.remove('Lookup')
df = df.loc[:,includelist]

lookuplist = df['Lookup'].to_list()
df = df.transpose()
df.columns = lookuplist
df = df.transpose()
lookuplist = df['Lookup'].value_counts().index.to_list()
lookuplist = sorted(lookuplist)

# %% [markdown]
# ## Contructing Main Dataframe

# %%
#Construction of maindf
colnames = ['Lookup','State','County','Date','Confirmed','Retail_mobility']
maindf = pd.DataFrame(index=range(0,len(lookuplist)*len(datelist)), columns=colnames)

#Start loop for confirmed
j = 0
for i in lookuplist:
    testdf = df.loc[i,:]
    timeseries = testdf[2:-1]
    date = timeseries.index.to_list()
    timeseries = timeseries.to_list()
    length = len(timeseries)
    maindf.iloc[j:(j+length),colnames.index('Lookup')] = i
    maindf.iloc[j:(j+length),colnames.index('State')] = testdf[0]
    maindf.iloc[j:(j+length),colnames.index('County')] = testdf[1]
    maindf.iloc[j:(j+length),colnames.index('Date')] = date
    maindf.iloc[j:(j+length),colnames.index('Confirmed')] = timeseries 
    j = j+length

maindf['Date'] = pd.to_datetime(maindf['Date'],format='%m/%d/%y')

#Start loop for mobility
usmobilitylookup
# Out:
# ['AbbevilleSouth Carolina',
#  'Acadia ParishLouisiana',
#  'AccomackVirginia',
#  'AdaIdaho',
#  'AdairIowa',
#  'AdairKentucky',
#  'AdairMissouri',
#  'AdairOklahoma',
#  'AdamsColorado',
#  'AdamsIllinois',
#  'AdamsIndiana',
#  'AdamsMississippi',
#  'AdamsNebraska',
#  'AdamsOhio',
#  'AdamsPennsylvania',
#  'AdamsWashington',
#  'AdamsWisconsin',
#  'AddisonVermont',
#  'AikenSouth Carolina',
#  'AitkinMinnesota',
#  'AlachuaFlorida',
#  'AlamanceNorth Carolina',
#  'AlamedaCalifornia',
#  'AlamosaColorado',
#  'AlbanyNew York',
#  'AlbanyWyoming',
#  'AlbemarleVirginia',
#  'AlconaMichigan',
#  'AlcornMississippi',
#  'AlexanderIllinois',
#  'AlexanderNorth Carolina',
#  'AlexandriaVirginia',
#  'AlgerMichigan',
#  'AllamakeeIowa',
#  'AlleganMichigan',
#  'AlleganyMaryland',
#  'AlleganyNew York',
#  'AlleghanyNorth Carolina',
#  'AlleghanyVirginia',
#  'AlleghenyPennsylvania',
#  'Allen ParishLouisiana',
#  'AllenIndiana',
#  'AllenKansas',
#  'AllenKentucky',
#  'AllenOhio',
#  'AllendaleSouth Carolina',
#  'AlpenaMichigan',
#  'AmadorCalifornia',
#  'AmeliaVirginia',
#  'AmherstVirginia',
#  'AmiteMississippi',
#  'AnchorageAlaska',
#  'AndersonKansas',
#  'AndersonKentucky',
#  'AndersonSouth Carolina',
#  'AndersonTennessee',
#  'AndersonTexas',
#  'AndrewMissouri',
#  'AndrewsTexas',
#  'AndroscogginMaine',
#  'AngelinaTexas',
#  'Anne ArundelMaryland',
#  'AnokaMinnesota',
#  'AnsonNorth Carolina',
#  'AntelopeNebraska',
#  'AntrimMichigan',
#  'ApacheArizona',
#  'AppanooseIowa',
#  'ApplingGeorgia',
#  'AppomattoxVirginia',
#  'AransasTexas',
#  'ArapahoeColorado',
#  'ArcherTexas',
#  'ArchuletaColorado',
#  'ArenacMichigan',
#  'ArkansasArkansas',
#  'ArlingtonVirginia',
#  'ArmstrongPennsylvania',
#  'AroostookMaine',
#  'Ascension ParishLouisiana',
#  'AsheNorth Carolina',
#  'AshlandOhio',
#  'AshlandWisconsin',
#  'AshleyArkansas',
#  'AshtabulaOhio',
#  'AsotinWashington',
#  'Assumption ParishLouisiana',
#  'AtascosaTexas',
#  'AtchisonKansas',
#  'AthensOhio',
#  'AtkinsonGeorgia',
#  'AtlanticNew Jersey',
#  'AtokaOklahoma',
#  'AttalaMississippi',
#  'AudrainMissouri',
#  'AudubonIowa',
#  'AuglaizeOhio',
#  'AugustaVirginia',
#  'AustinTexas',
#  'AutaugaAlabama',
#  'AveryNorth Carolina',
#  'Avoyelles ParishLouisiana',
#  'BaconGeorgia',
#  'BaileyTexas',
#  'BakerFlorida',
#  'BakerOregon',
#  'BaldwinAlabama',
#  'BaldwinGeorgia',
#  'BallardKentucky',
#  'BaltimoreMaryland',
#  'BambergSouth Carolina',
#  'BanderaTexas',
#  'BanksGeorgia',
#  'BannockIdaho',
#  'BaragaMichigan',
#  'BarbourAlabama',
#  'BarbourWest Virginia',
#  'BarnesNorth Dakota',
#  'BarnstableMassachusetts',
#  'BarnwellSouth Carolina',
#  'BarrenKentucky',
#  'BarronWisconsin',
#  'BarrowGeorgia',
#  'BarryMichigan',
#  'BarryMissouri',
#  'BartholomewIndiana',
#  'BartonKansas',
#  'BartonMissouri',
#  'BartowGeorgia',
#  'BastropTexas',
#  'BatesMissouri',
#  'BathKentucky',
#  'BathVirginia',
#  'BaxterArkansas',
#  'BayFlorida',
#  'BayMichigan',
#  'BayfieldWisconsin',
#  'BeadleSouth Dakota',
#  'Bear LakeIdaho',
#  'BeaufortNorth Carolina',
#  'BeaufortSouth Carolina',
#  'Beauregard ParishLouisiana',
#  'BeaverPennsylvania',
#  'BeaverUtah',
#  'BeaverheadMontana',
#  'BeckerMinnesota',
#  'BeckhamOklahoma',
#  'BedfordPennsylvania',
#  'BedfordTennessee',
#  'BedfordVirginia',
#  'BeeTexas',
#  'BelknapNew Hampshire',
#  'BellKentucky',
#  'BellTexas',
#  'BelmontOhio',
#  'BeltramiMinnesota',
#  'Ben HillGeorgia',
#  'BenewahIdaho',
#  'BenningtonVermont',
#  'BentColorado',
#  'BentonArkansas',
#  'BentonIndiana',
#  'BentonIowa',
#  'BentonMinnesota',
#  'BentonMississippi',
#  'BentonMissouri',
#  'BentonOregon',
#  'BentonTennessee',
#  'BentonWashington',
#  'BenzieMichigan',
#  'BergenNew Jersey',
#  'BerkeleySouth Carolina',
#  'BerkeleyWest Virginia',
#  'BerksPennsylvania',
#  'BerkshireMassachusetts',
#  'BernalilloNew Mexico',
#  'BerrienGeorgia',
#  'BerrienMichigan',
#  'BertieNorth Carolina',
#  'BethelAlaska',
#  'BexarTexas',
#  'BibbAlabama',
#  'BibbGeorgia',
#  'Bienville ParishLouisiana',
#  'Big HornMontana',
#  'Big HornWyoming',
#  'Big StoneMinnesota',
#  'BinghamIdaho',
#  'Black HawkIowa',
#  'BlackfordIndiana',
#  'BladenNorth Carolina',
#  'BlaineIdaho',
#  'BlaineMontana',
#  'BlaineOklahoma',
#  'BlairPennsylvania',
#  'BlancoTexas',
#  'BlandVirginia',
#  'BleckleyGeorgia',
#  'BledsoeTennessee',
#  'BlountAlabama',
#  'BlountTennessee',
#  'Blue EarthMinnesota',
#  'BoiseIdaho',
#  'BolivarMississippi',
#  'BollingerMissouri',
#  'Bon HommeSouth Dakota',
#  'BondIllinois',
#  'BonnerIdaho',
#  'BonnevilleIdaho',
#  'BooneArkansas',
#  'BooneIllinois',
#  'BooneIndiana',
#  'BooneIowa',
#  'BooneKentucky',
#  'BooneMissouri',
#  'BooneWest Virginia',
#  'BosqueTexas',
#  'Bossier ParishLouisiana',
#  'BotetourtVirginia',
#  'BottineauNorth Dakota',
#  'BoulderColorado',
#  'BoundaryIdaho',
#  'BourbonKansas',
#  'BourbonKentucky',
#  'BowieTexas',
#  'Box ButteNebraska',
#  'Box ElderUtah',
#  'BoydKentucky',
#  'BoyleKentucky',
#  'BrackenKentucky',
#  'BradfordFlorida',
#  'BradfordPennsylvania',
#  'BradleyArkansas',
#  'BradleyTennessee',
#  'BranchMichigan',
#  'BrantleyGeorgia',
#  'BraxtonWest Virginia',
#  'BrazoriaTexas',
#  'BrazosTexas',
#  'BreathittKentucky',
#  'BreckinridgeKentucky',
#  'BremerIowa',
#  'BrevardFlorida',
#  'BrewsterTexas',
#  'BristolMassachusetts',
#  'BristolRhode Island',
#  'BristolVirginia',
#  'BroadwaterMontana',
#  'BronxNew York',
#  'BrookeWest Virginia',
#  'BrookingsSouth Dakota',
#  'BrooksGeorgia',
#  'BrooksTexas',
#  'BroomeNew York',
#  'BroomfieldColorado',
#  'BrowardFlorida',
#  'BrownIndiana',
#  'BrownKansas',
#  'BrownMinnesota',
#  'BrownOhio',
#  'BrownSouth Dakota',
#  'BrownTexas',
#  'BrownWisconsin',
#  'BruleSouth Dakota',
#  'BrunswickNorth Carolina',
#  'BrunswickVirginia',
#  'BryanGeorgia',
#  'BryanOklahoma',
#  'BuchananIowa',
#  'BuchananMissouri',
#  'BuchananVirginia',
#  'BuckinghamVirginia',
#  'BucksPennsylvania',
#  'Buena VistaIowa',
#  'Buena VistaVirginia',
#  'BuffaloNebraska',
#  'BuffaloWisconsin',
#  'BullittKentucky',
#  'BullochGeorgia',
#  'BullockAlabama',
#  'BuncombeNorth Carolina',
#  'BureauIllinois',
#  'BurkeGeorgia',
#  'BurkeNorth Carolina',
#  'BurleighNorth Dakota',
#  'BurlesonTexas',
#  'BurlingtonNew Jersey',
#  'BurnetTexas',
#  'BurnettWisconsin',
#  'BurtNebraska',
#  'ButlerAlabama',
#  'ButlerIowa',
#  'ButlerKansas',
#  'ButlerKentucky',
#  'ButlerMissouri',
#  'ButlerNebraska',
#  'ButlerOhio',
#  'ButlerPennsylvania',
#  'ButteCalifornia',
#  'ButteSouth Dakota',
#  'ButtsGeorgia',
#  'CabarrusNorth Carolina',
#  'CabellWest Virginia',
#  'CacheUtah',
#  'Caddo ParishLouisiana',
#  'CaddoOklahoma',
#  'CalaverasCalifornia',
#  'Calcasieu ParishLouisiana',
#  'Caldwell ParishLouisiana',
#  'CaldwellKentucky',
#  'CaldwellMissouri',
#  'CaldwellNorth Carolina',
#  'CaldwellTexas',
#  'CaledoniaVermont',
#  'CalhounAlabama',
#  'CalhounFlorida',
#  'CalhounIowa',
#  'CalhounMichigan',
#  'CalhounMississippi',
#  'CalhounSouth Carolina',
#  'CalhounTexas',
#  'CallahanTexas',
#  'CallawayMissouri',
#  'CallowayKentucky',
#  'CalumetWisconsin',
#  'CalvertMaryland',
#  'CambriaPennsylvania',
#  'CamdenGeorgia',
#  'CamdenMissouri',
#  'CamdenNew Jersey',
#  'CamdenNorth Carolina',
#  'Cameron ParishLouisiana',
#  'CameronTexas',
#  'CampTexas',
#  'CampbellKentucky',
#  'CampbellTennessee',
#  'CampbellVirginia',
#  'CampbellWyoming',
#  'CanadianOklahoma',
#  'CandlerGeorgia',
#  'CannonTennessee',
#  'CanyonIdaho',
#  'Cape GirardeauMissouri',
#  'Cape MayNew Jersey',
#  'CarbonMontana',
#  'CarbonPennsylvania',
#  'CarbonUtah',
#  'CarbonWyoming',
#  'CaribouIdaho',
#  'CarlisleKentucky',
#  'CarltonMinnesota',
#  'CarolineMaryland',
#  'CarolineVirginia',
#  'CarrollArkansas',
#  'CarrollGeorgia',
#  'CarrollIllinois',
#  'CarrollIndiana',
#  'CarrollIowa',
#  'CarrollKentucky',
#  'CarrollMaryland',
#  'CarrollMississippi',
#  'CarrollMissouri',
#  'CarrollNew Hampshire',
#  'CarrollOhio',
#  'CarrollTennessee',
#  'CarrollVirginia',
#  'Carson CityNevada',
#  'CarsonTexas',
#  'CarterKentucky',
#  'CarterOklahoma',
#  'CarterTennessee',
#  'CarteretNorth Carolina',
#  'CarverMinnesota',
#  'CascadeMontana',
#  'CaseyKentucky',
#  'CassIllinois',
#  'CassIndiana',
#  'CassIowa',
#  'CassMichigan',
#  'CassMinnesota',
#  'CassMissouri',
#  'CassNebraska',
#  'CassNorth Dakota',
#  'CassTexas',
#  'CassiaIdaho',
#  'CastroTexas',
#  'CaswellNorth Carolina',
#  'Catahoula ParishLouisiana',
#  'CatawbaNorth Carolina',
#  'CatoosaGeorgia',
#  'CattaraugusNew York',
#  'CayugaNew York',
#  'CecilMaryland',
#  'CedarIowa',
#  'CedarMissouri',
#  'CedarNebraska',
#  'CentrePennsylvania',
#  'Cerro GordoIowa',
#  'ChaffeeColorado',
#  'ChambersAlabama',
#  'ChambersTexas',
#  'ChampaignIllinois',
#  'ChampaignOhio',
#  'CharitonMissouri',
#  'Charles CityVirginia',
#  'Charles MixSouth Dakota',
#  'CharlesMaryland',
#  'CharlestonSouth Carolina',
#  'CharlevoixMichigan',
#  'CharlotteFlorida',
#  'CharlotteVirginia',
#  'CharlottesvilleVirginia',
#  'CharltonGeorgia',
#  'ChathamGeorgia',
#  'ChathamNorth Carolina',
#  'ChattahoocheeGeorgia',
#  'ChattoogaGeorgia',
#  'ChautauquaNew York',
#  'ChavesNew Mexico',
#  'CheathamTennessee',
#  'CheboyganMichigan',
#  'ChelanWashington',
#  'ChemungNew York',
#  'ChenangoNew York',
#  'CherokeeAlabama',
#  'CherokeeGeorgia',
#  'CherokeeIowa',
#  'CherokeeKansas',
#  'CherokeeNorth Carolina',
#  'CherokeeOklahoma',
#  'CherokeeSouth Carolina',
#  'CherokeeTexas',
#  'CherryNebraska',
#  'ChesapeakeVirginia',
#  'CheshireNew Hampshire',
#  'ChesterPennsylvania',
#  'ChesterSouth Carolina',
#  'ChesterTennessee',
#  'ChesterfieldSouth Carolina',
#  'ChesterfieldVirginia',
#  'CheyenneNebraska',
#  'ChickasawIowa',
#  'ChickasawMississippi',
#  'ChicotArkansas',
#  'ChildressTexas',
#  'ChiltonAlabama',
#  'ChippewaMichigan',
#  'ChippewaMinnesota',
#  'ChippewaWisconsin',
#  'ChisagoMinnesota',
#  'ChittendenVermont',
#  'ChoctawAlabama',
#  'ChoctawOklahoma',
#  'ChowanNorth Carolina',
#  'ChristianIllinois',
#  'ChristianKentucky',
#  'ChristianMissouri',
#  'ChurchillNevada',
#  'CibolaNew Mexico',
#  'CitrusFlorida',
#  'ClackamasOregon',
#  'Claiborne ParishLouisiana',
#  'ClaiborneMississippi',
#  'ClaiborneTennessee',
#  'ClallamWashington',
#  'ClareMichigan',
#  'ClarendonSouth Carolina',
#  'ClarionPennsylvania',
#  'ClarkArkansas',
#  'ClarkIllinois',
#  'ClarkIndiana',
#  'ClarkKentucky',
#  'ClarkMissouri',
#  'ClarkNevada',
#  'ClarkOhio',
#  'ClarkWashington',
#  'ClarkWisconsin',
#  'ClarkeAlabama',
#  'ClarkeGeorgia',
#  'ClarkeIowa',
#  'ClarkeMississippi',
#  'ClarkeVirginia',
#  'ClatsopOregon',
#  'ClayAlabama',
#  'ClayArkansas',
#  'ClayFlorida',
#  'ClayIllinois',
#  'ClayIndiana',
#  'ClayIowa',
#  'ClayKansas',
#  'ClayKentucky',
#  'ClayMinnesota',
#  'ClayMississippi',
#  'ClayMissouri',
#  'ClayNebraska',
#  'ClayNorth Carolina',
#  'ClaySouth Dakota',
#  'ClayTennessee',
#  'ClayTexas',
#  'ClaytonGeorgia',
#  'ClaytonIowa',
#  'Clear CreekColorado',
#  'ClearfieldPennsylvania',
#  'ClearwaterIdaho',
#  'ClearwaterMinnesota',
#  'CleburneAlabama',
#  'CleburneArkansas',
#  'ClermontOhio',
#  'ClevelandArkansas',
#  'ClevelandNorth Carolina',
#  'ClevelandOklahoma',
#  'ClinchGeorgia',
#  'ClintonIllinois',
#  'ClintonIndiana',
#  'ClintonIowa',
#  'ClintonKentucky',
#  'ClintonMichigan',
#  'ClintonMissouri',
#  'ClintonNew York',
#  'ClintonOhio',
#  'ClintonPennsylvania',
#  'CloudKansas',
#  'CoahomaMississippi',
#  'CoalOklahoma',
#  'CobbGeorgia',
#  'CochiseArizona',
#  'CockeTennessee',
#  'CoconinoArizona',
#  'CodingtonSouth Dakota',
#  'CoffeeAlabama',
#  'CoffeeGeorgia',
#  'CoffeeTennessee',
#  'CoffeyKansas',
#  'CokeTexas',
#  'ColbertAlabama',
#  'ColeMissouri',
#  'ColemanTexas',
#  'ColesIllinois',
#  'ColfaxNebraska',
#  'ColfaxNew Mexico',
#  'ColletonSouth Carolina',
#  'CollierFlorida',
#  'CollinTexas',
#  'Colonial HeightsVirginia',
#  'ColoradoTexas',
#  'ColquittGeorgia',
#  'ColumbiaArkansas',
#  'ColumbiaFlorida',
#  'ColumbiaGeorgia',
#  'ColumbiaNew York',
#  'ColumbiaOregon',
#  'ColumbiaPennsylvania',
#  'ColumbiaWisconsin',
#  'ColumbianaOhio',
#  'ColumbusNorth Carolina',
#  'ColusaCalifornia',
#  'ComalTexas',
#  'ComancheOklahoma',
#  'ComancheTexas',
#  'Concordia ParishLouisiana',
#  'ConecuhAlabama',
#  'ConejosColorado',
#  'Contra CostaCalifornia',
#  'ConverseWyoming',
#  'ConwayArkansas',
#  'CookGeorgia',
#  'CookIllinois',
#  'CookMinnesota',
#  'CookeTexas',
#  'CooperMissouri',
#  'CoosNew Hampshire',
#  'CoosOregon',
#  'CoosaAlabama',
#  'CopiahMississippi',
#  'CortlandNew York',
#  'CoryellTexas',
#  'CoshoctonOhio',
#  'CottonOklahoma',
#  'CottonwoodMinnesota',
#  'CovingtonAlabama',
#  'CovingtonMississippi',
#  'CovingtonVirginia',
#  'CowetaGeorgia',
#  'CowleyKansas',
#  'CowlitzWashington',
#  'CraigOklahoma',
#  'CraigVirginia',
#  'CraigheadArkansas',
#  'CraneTexas',
#  'CravenNorth Carolina',
#  'CrawfordArkansas',
#  'CrawfordGeorgia',
#  'CrawfordIllinois',
#  'CrawfordIndiana',
#  'CrawfordIowa',
#  'CrawfordKansas',
#  'CrawfordMichigan',
#  'CrawfordMissouri',
#  'CrawfordOhio',
#  'CrawfordPennsylvania',
#  'CrawfordWisconsin',
#  'CreekOklahoma',
#  'CrenshawAlabama',
#  'CrispGeorgia',
#  'CrittendenArkansas',
#  'CrittendenKentucky',
#  'CrockettTennessee',
#  'CrockettTexas',
#  'CrookOregon',
#  'CrookWyoming',
#  'CrosbyTexas',
#  'CrossArkansas',
#  'Crow WingMinnesota',
#  'CulbersonTexas',
#  'CullmanAlabama',
#  'CulpeperVirginia',
#  'CumberlandIllinois',
#  'CumberlandMaine',
#  'CumberlandNew Jersey',
#  'CumberlandNorth Carolina',
#  'CumberlandPennsylvania',
#  'CumberlandTennessee',
#  'CumberlandVirginia',
#  'CumingNebraska',
#  'CurrituckNorth Carolina',
#  'CurryNew Mexico',
#  'CurryOregon',
#  'CusterMontana',
#  'CusterNebraska',
#  'CusterOklahoma',
#  'CusterSouth Dakota',
#  'CuyahogaOhio',
#  'DadeGeorgia',
#  'DadeMissouri',
#  'DakotaMinnesota',
#  'DakotaNebraska',
#  'DaleAlabama',
#  'DallamTexas',
#  'DallasAlabama',
#  'DallasArkansas',
#  'DallasIowa',
#  'DallasMissouri',
#  'DallasTexas',
#  'DaneWisconsin',
#  'DanvilleVirginia',
#  'DareNorth Carolina',
#  'DarkeOhio',
#  'DarlingtonSouth Carolina',
#  'DauphinPennsylvania',
#  'DavidsonNorth Carolina',
#  'DavidsonTennessee',
#  'DavieNorth Carolina',
#  'DaviessIndiana',
#  'DaviessKentucky',
#  'DaviessMissouri',
#  'DavisIowa',
#  'DavisUtah',
#  'DavisonSouth Dakota',
#  'DawesNebraska',
#  'DawsonGeorgia',
#  'DawsonMontana',
#  'DawsonNebraska',
#  'DawsonTexas',
#  'De Soto ParishLouisiana',
#  'De WittIllinois',
#  'DeKalbAlabama',
#  'DeKalbGeorgia',
#  'DeKalbIllinois',
#  'DeKalbIndiana',
#  'DeKalbMissouri',
#  'DeKalbTennessee',
#  'DeSotoFlorida',
#  'DeSotoMississippi',
#  'DeWittTexas',
#  'Deaf SmithTexas',
#  'DearbornIndiana',
#  'DecaturGeorgia',
#  'DecaturIndiana',
#  'DecaturIowa',
#  'DecaturTennessee',
#  'Deer LodgeMontana',
#  'DefianceOhio',
#  'Del NorteCalifornia',
#  'DelawareIndiana',
#  'DelawareIowa',
#  'DelawareNew York',
#  'DelawareOhio',
#  'DelawareOklahoma',
#  'DelawarePennsylvania',
#  'DeltaColorado',
#  'DeltaMichigan',
#  'DeltaTexas',
#  'DentMissouri',
#  'DentonTexas',
#  'DenverColorado',
#  'Des MoinesIowa',
#  'DeschutesOregon',
#  'DeshaArkansas',
#  'DeuelNebraska',
#  'DeweySouth Dakota',
#  'DickensonVirginia',
#  'DickinsonIowa',
#  'DickinsonKansas',
#  'DickinsonMichigan',
#  'DicksonTennessee',
#  'DillonSouth Carolina',
#  'DimmitTexas',
#  'DinwiddieVirginia',
#  'DixieFlorida',
#  'DixonNebraska',
#  'DodgeGeorgia',
#  'DodgeMinnesota',
#  'DodgeNebraska',
#  'DodgeWisconsin',
#  'DoniphanKansas',
#  'DonleyTexas',
#  'DoolyGeorgia',
#  'DoorWisconsin',
#  'DorchesterMaryland',
#  'DorchesterSouth Carolina',
#  'DoughertyGeorgia',
#  'DouglasColorado',
#  'DouglasGeorgia',
#  'DouglasIllinois',
#  'DouglasKansas',
#  'DouglasMinnesota',
#  'DouglasMissouri',
#  'DouglasNebraska',
#  'DouglasNevada',
#  'DouglasOregon',
#  'DouglasWashington',
#  'DouglasWisconsin',
#  'Doña AnaNew Mexico',
#  'DrewArkansas',
#  'DuPageIllinois',
#  'DuboisIndiana',
#  'DubuqueIowa',
#  'DuchesneUtah',
#  'DukesMassachusetts',
#  'DunklinMissouri',
#  'DunnNorth Dakota',
#  'DunnWisconsin',
#  'DuplinNorth Carolina',
#  'DurhamNorth Carolina',
#  'DutchessNew York',
#  'DuvalFlorida',
#  'DuvalTexas',
#  'DyerTennessee',
#  'EagleColorado',
#  'EarlyGeorgia',
#  'East Baton Rouge ParishLouisiana',
#  'East Feliciana ParishLouisiana',
#  'EastlandTexas',
#  'EatonMichigan',
#  'Eau ClaireWisconsin',
#  'EctorTexas',
#  'EddyNew Mexico',
#  'EdgarIllinois',
#  'EdgecombeNorth Carolina',
#  'EdgefieldSouth Carolina',
#  'EdmonsonKentucky',
#  'EdwardsIllinois',
#  'EffinghamGeorgia',
#  'EffinghamIllinois',
#  'El DoradoCalifornia',
#  'El PasoColorado',
#  'El PasoTexas',
#  'ElbertColorado',
#  'ElbertGeorgia',
#  'ElkPennsylvania',
#  'ElkhartIndiana',
#  'ElkoNevada',
#  'EllisKansas',
#  'EllisTexas',
#  'EllsworthKansas',
#  'ElmoreAlabama',
#  'ElmoreIdaho',
#  'EmanuelGeorgia',
#  'EmeryUtah',
#  'EmmetIowa',
#  'EmmetMichigan',
#  'EmporiaVirginia',
#  'ErathTexas',
#  'ErieNew York',
#  'ErieOhio',
#  'EriePennsylvania',
#  'EscambiaAlabama',
#  'EscambiaFlorida',
#  'EssexMassachusetts',
#  'EssexNew Jersey',
#  'EssexNew York',
#  'EssexVermont',
#  'EssexVirginia',
#  'EstillKentucky',
#  'EtowahAlabama',
#  'Evangeline ParishLouisiana',
#  'EvansGeorgia',
#  'Fairbanks North StarAlaska',
#  'FairfaxVirginia',
#  'FairfieldConnecticut',
#  'FairfieldOhio',
#  'FairfieldSouth Carolina',
#  'Fall RiverSouth Dakota',
#  'Falls ChurchVirginia',
#  'FallsTexas',
#  'FanninGeorgia',
#  'FanninTexas',
#  'FaribaultMinnesota',
#  'FaulknerArkansas',
#  'FauquierVirginia',
#  'FayetteAlabama',
#  'FayetteGeorgia',
#  'FayetteIllinois',
#  'FayetteIndiana',
#  'FayetteIowa',
#  'FayetteKentucky',
#  'FayetteOhio',
#  'FayettePennsylvania',
#  'FayetteTennessee',
#  'FayetteTexas',
#  'FayetteWest Virginia',
#  'FentressTennessee',
#  'FergusMontana',
#  'FerryWashington',
#  'FillmoreMinnesota',
#  'FillmoreNebraska',
#  'FinneyKansas',
#  'FlaglerFlorida',
#  'FlatheadMontana',
#  'FlemingKentucky',
#  'FlorenceSouth Carolina',
#  'FlorenceWisconsin',
#  'FloydGeorgia',
#  'FloydIndiana',
#  'FloydIowa',
#  'FloydKentucky',
#  'FloydTexas',
#  'FloydVirginia',
#  'FluvannaVirginia',
#  'Fond du LacWisconsin',
#  'FordIllinois',
#  'FordKansas',
#  'ForestWisconsin',
#  'ForrestMississippi',
#  'ForsythGeorgia',
#  'ForsythNorth Carolina',
#  'Fort BendTexas',
#  'FountainIndiana',
#  'Franklin ParishLouisiana',
#  'FranklinAlabama',
#  'FranklinArkansas',
#  'FranklinFlorida',
#  'FranklinGeorgia',
#  'FranklinIdaho',
#  'FranklinIllinois',
#  'FranklinIndiana',
#  'FranklinIowa',
#  'FranklinKansas',
#  'FranklinKentucky',
#  'FranklinMaine',
#  'FranklinMassachusetts',
#  'FranklinMissouri',
#  'FranklinNew York',
#  'FranklinNorth Carolina',
#  'FranklinOhio',
#  'FranklinPennsylvania',
#  'FranklinTennessee',
#  'FranklinTexas',
#  'FranklinVermont',
#  'FranklinVirginia',
#  'FranklinWashington',
#  'FrederickMaryland',
#  'FrederickVirginia',
#  'FredericksburgVirginia',
#  'FreebornMinnesota',
#  'FreestoneTexas',
#  'FremontColorado',
#  'FremontIdaho',
#  'FremontIowa',
#  'FremontWyoming',
#  'FresnoCalifornia',
#  'FrioTexas',
#  'FultonArkansas',
#  'FultonGeorgia',
#  'FultonIllinois',
#  'FultonIndiana',
#  'FultonKentucky',
#  'FultonNew York',
#  'FultonOhio',
#  'FultonPennsylvania',
#  'GadsdenFlorida',
#  'GageNebraska',
#  'GainesTexas',
#  'GalaxVirginia',
#  'GallatinIllinois',
#  'GallatinKentucky',
#  'GallatinMontana',
#  'GalliaOhio',
#  'GalvestonTexas',
#  'GarfieldColorado',
#  'GarfieldOklahoma',
#  'GarfieldUtah',
#  'GarlandArkansas',
#  'GarrardKentucky',
#  'GarrettMaryland',
#  'GarvinOklahoma',
#  'GarzaTexas',
#  'GasconadeMissouri',
#  'GastonNorth Carolina',
#  'GatesNorth Carolina',
#  'GearyKansas',
#  'GeaugaOhio',
#  'GemIdaho',
#  'GeneseeMichigan',
#  'GeneseeNew York',
#  'GenevaAlabama',
#  'GentryMissouri',
#  'GeorgeMississippi',
#  'GeorgetownSouth Carolina',
#  'GibsonIndiana',
#  'GibsonTennessee',
#  'GilaArizona',
#  'GilchristFlorida',
#  'GilesTennessee',
#  'GilesVirginia',
#  'GillespieTexas',
#  'GilmerGeorgia',
#  'GilpinColorado',
#  'GlacierMontana',
#  'GladesFlorida',
#  'GladwinMichigan',
#  'GlennCalifornia',
#  'GloucesterNew Jersey',
#  'GloucesterVirginia',
#  'GlynnGeorgia',
#  'GogebicMichigan',
#  'GoliadTexas',
#  'GonzalesTexas',
#  'GoochlandVirginia',
#  'GoodhueMinnesota',
#  'GoodingIdaho',
#  'GordonGeorgia',
#  'GoshenWyoming',
#  'GradyGeorgia',
#  'GradyOklahoma',
#  'GraftonNew Hampshire',
#  'GrahamArizona',
#  'GrahamNorth Carolina',
#  'GraingerTennessee',
#  'Grand ForksNorth Dakota',
#  'Grand IsleVermont',
#  'Grand TraverseMichigan',
#  'GrandColorado',
#  'GrandUtah',
#  'Grant ParishLouisiana',
#  'GrantArkansas',
#  'GrantIndiana',
#  'GrantKansas',
#  'GrantKentucky',
#  'GrantMinnesota',
#  'GrantNew Mexico',
#  'GrantOregon',
#  'GrantSouth Dakota',
#  'GrantWashington',
#  'GrantWest Virginia',
#  'GrantWisconsin',
#  'GranvilleNorth Carolina',
#  'GratiotMichigan',
#  'GravesKentucky',
#  'GrayTexas',
#  'Grays HarborWashington',
#  'GraysonKentucky',
#  'GraysonTexas',
#  'GraysonVirginia',
#  'Green LakeWisconsin',
#  'GreenKentucky',
#  'GreenWisconsin',
#  'GreenbrierWest Virginia',
#  'GreeneAlabama',
#  'GreeneArkansas',
#  'GreeneGeorgia',
#  'GreeneIllinois',
#  'GreeneIndiana',
#  'GreeneIowa',
#  'GreeneMississippi',
#  'GreeneMissouri',
#  'GreeneNew York',
#  'GreeneNorth Carolina',
#  'GreeneOhio',
#  'GreenePennsylvania',
#  'GreeneTennessee',
#  'GreeneVirginia',
#  'GreenleeArizona',
#  'GreensvilleVirginia',
#  'GreenupKentucky',
#  'GreenvilleSouth Carolina',
#  'GreenwoodKansas',
#  'GreenwoodSouth Carolina',
#  'GreerOklahoma',
#  'GreggTexas',
#  ...]

# %%
countymobility = usmobility.loc['WestonWyoming','date':]
datelength = len(pd.date_range(min(countymobility['date']),max(countymobility['date'])))
countyretail = usmobility.loc['WestonWyoming','retail_and_recreation_percent_change_from_baseline'].to_list()

startindex = maindf[maindf['Lookup']=='WestonWyoming'][maindf['Date']==min(countymobility['date'])].index
endindex = startindex + datelength
daterange = range(startindex[0],endindex[0])
maindf.iloc[range(startindex[0],endindex[0]),:]
#maindf.iloc[range(startindex[0],endindex[0]),colnames.index('Retail_mobility')] = 1
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#                Lookup   State   County       Date Confirmed Retail_mobility
# 307549  WestonWyoming  Weston  Wyoming 2020-02-16         0             NaN
# 307550  WestonWyoming  Weston  Wyoming 2020-02-17         0             NaN
# 307551  WestonWyoming  Weston  Wyoming 2020-02-18         0             NaN
# 307552  WestonWyoming  Weston  Wyoming 2020-02-19         0             NaN
# 307553  WestonWyoming  Weston  Wyoming 2020-02-20         0             NaN
# 307554  WestonWyoming  Weston  Wyoming 2020-02-21         0             NaN
# 307555  WestonWyoming  Weston  Wyoming 2020-02-22         0             NaN
# 307556  WestonWyoming  Weston  Wyoming 2020-02-23         0             NaN
# 307557  WestonWyoming  Weston  Wyoming 2020-02-24         0             NaN
# 307558  WestonWyoming  Weston  Wyoming 2020-02-25         0             NaN
# 307559  WestonWyoming  Weston  Wyoming 2020-02-26         0             NaN
# 307560  WestonWyoming  Weston  Wyoming 2020-02-27         0             NaN
# 307561  WestonWyoming  Weston  Wyoming 2020-02-28         0             NaN
# 307562  WestonWyoming  Weston  Wyoming 2020-02-29         0             NaN
# 307563  WestonWyoming  Weston  Wyoming 2020-03-01         0             NaN
# 307564  WestonWyoming  Weston  Wyoming 2020-03-02         0             NaN
# 307565  WestonWyoming  Weston  Wyoming 2020-03-03         0             NaN
# 307566  WestonWyoming  Weston  Wyoming 2020-03-04         0             NaN
# 307567  WestonWyoming  Weston  Wyoming 2020-03-05         0             NaN
# 307568  WestonWyoming  Weston  Wyoming 2020-03-06         0             NaN
# 307569  WestonWyoming  Weston  Wyoming 2020-03-07         0             NaN
# 307570  WestonWyoming  Weston  Wyoming 2020-03-08         0             NaN
# 307571  WestonWyoming  Weston  Wyoming 2020-03-09         0             NaN
# 307572  WestonWyoming  Weston  Wyoming 2020-03-10         0             NaN
# 307573  WestonWyoming  Weston  Wyoming 2020-03-11         0             NaN
# 307574  WestonWyoming  Weston  Wyoming 2020-03-12         0             NaN
# 307575  WestonWyoming  Weston  Wyoming 2020-03-13         0             NaN
# 307576  WestonWyoming  Weston  Wyoming 2020-03-14         0             NaN
# 307577  WestonWyoming  Weston  Wyoming 2020-03-15         0             NaN
# 307578  WestonWyoming  Weston  Wyoming 2020-03-16         0             NaN
# 307579  WestonWyoming  Weston  Wyoming 2020-03-17         0             NaN
# 307580  WestonWyoming  Weston  Wyoming 2020-03-18         0             NaN
# 307581  WestonWyoming  Weston  Wyoming 2020-03-19         0             NaN
# 307582  WestonWyoming  Weston  Wyoming 2020-03-20         0             NaN
# 307583  WestonWyoming  Weston  Wyoming 2020-03-21         0             NaN
# 307584  WestonWyoming  Weston  Wyoming 2020-03-22         0             NaN
# 307585  WestonWyoming  Weston  Wyoming 2020-03-23         0             NaN
# 307586  WestonWyoming  Weston  Wyoming 2020-03-24         0             NaN
# 307587  WestonWyoming  Weston  Wyoming 2020-03-25         0             NaN
# 307588  WestonWyoming  Weston  Wyoming 2020-03-26         0             NaN
# 307589  WestonWyoming  Weston  Wyoming 2020-03-27         0             NaN
# 307590  WestonWyoming  Weston  Wyoming 2020-03-28         0             NaN
# 307591  WestonWyoming  Weston  Wyoming 2020-03-29         0             NaN
# 307592  WestonWyoming  Weston  Wyoming 2020-03-30         0             NaN
# 307593  WestonWyoming  Weston  Wyoming 2020-03-31         0             NaN
# 307594  WestonWyoming  Weston  Wyoming 2020-04-01         0             NaN
# 307595  WestonWyoming  Weston  Wyoming 2020-04-02         0             NaN
# 307596  WestonWyoming  Weston  Wyoming 2020-04-03         0             NaN
# 307597  WestonWyoming  Weston  Wyoming 2020-04-04         0             NaN
# 307598  WestonWyoming  Weston  Wyoming 2020-04-05         0             NaN
# 307599  WestonWyoming  Weston  Wyoming 2020-04-06         0             NaN
# 307600  WestonWyoming  Weston  Wyoming 2020-04-07         0             NaN
# 307601  WestonWyoming  Weston  Wyoming 2020-04-08         0             NaN
# 307602  WestonWyoming  Weston  Wyoming 2020-04-09         0             NaN
# 307603  WestonWyoming  Weston  Wyoming 2020-04-10         0             NaN
